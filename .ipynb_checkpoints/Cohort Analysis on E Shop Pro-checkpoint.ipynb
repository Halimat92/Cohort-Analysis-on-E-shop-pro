# %% [markdown]
# ### Data Description
#
# 1.	InvoiceNo:   A unique identifier for each invoice or transaction, often used for
#                  tracking and reference purposes.
# 2.	StockCode:   A code or identifier associated with a specific product or item in the e-
#                  commerce store's inventory, used for cataloging and tracking purposes.
# 3.	Description: A categorical feature that provides a brief textual description of the
#                  product or item being sold, offering clarity to customers about what they are
#                  purchasing.
# 4.	Quantity:   The quantity or number of units of a product that were included in the
#                 transaction, indicating the purchase volume for each item.
# 5.	InvoiceDate: The date and time when the transaction or invoice was generated,
#                   offering insights into when purchases were made and allowing for temporal
#                   analysis.
# 6.	UnitPrice:   Indicating the total cost of the items purchased.
# 7.	CustomerID:  A unique identifier associated with each customer or shopper,
#                  allowing for customer-specific analysis and tracking of individual purchasing
#                  behavior.
# 8.	Country: The name of the country where the customer is located or where the
#                   transaction occurred.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from operator import attrgetter

# %%
data = pd.read_csv("e_commerce.csv")
print('E-Shop Pro Dataset:')
data.head()
# Out:
# E-Shop Pro Dataset:
#   InvoiceNo       InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365  01/12/2010 08:26     17850.0    SC1734  Electronics        65
# 1    536365  01/12/2010 08:26     17850.0    SC2088    Furniture        95
# 2    536365  01/12/2010 08:26     17850.0    SC3463        Books        78
# 3    536365  01/12/2010 08:26     17850.0    SC6228         Toys        15
# 4    536365  01/12/2010 08:26     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country
# 0      10.23         Egypt
# 1      19.61          Mali
# 2      61.49          Mali
# 3      24.73  South Africa
# 4      38.83        Rwanda

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   InvoiceDate  541909 non-null  object
#  2   CustomerID   406829 non-null  float64
#  3   StockCode    541909 non-null  object
#  4   Description  541909 non-null  object
#  5   Quantity     541909 non-null  int64
#  6   UnitPrice    541909 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
data.describe()
# Out:
#           CustomerID       Quantity      UnitPrice
# count  406829.000000  541909.000000  541909.000000
# mean    15287.690570      50.534748      50.476354
# std      1713.600303      28.849367      28.564775
# min     12346.000000       1.000000       1.000000
# 25%     13953.000000      26.000000      25.750000
# 50%     15152.000000      51.000000      50.430000
# 75%     16791.000000      76.000000      75.180000
# max     18287.000000     100.000000     100.000000

# %%
data['InvoiceDate'] = pd.to_datetime(data['InvoiceDate'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   InvoiceDate  541909 non-null  datetime64[ns]
#  2   CustomerID   406829 non-null  float64
#  3   StockCode    541909 non-null  object
#  4   Description  541909 non-null  object
#  5   Quantity     541909 non-null  int64
#  6   UnitPrice    541909 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# check for the total number of null values

data.isnull().sum()
# Out:
# InvoiceNo           0
# InvoiceDate         0
# CustomerID     135080
# StockCode           0
# Description         0
# Quantity            0
# UnitPrice           0
# Country             0
# dtype: int64

# %%
# delete rows with null values

data.dropna(inplace=True)

# %%
# recheck the total number of null values

data.isnull().sum()
# Out:
# InvoiceNo      0
# InvoiceDate    0
# CustomerID     0
# StockCode      0
# Description    0
# Quantity       0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
duplicates = data[data.duplicated()]
print("Duplicate rows:")
print(duplicates)
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [InvoiceNo, InvoiceDate, CustomerID, StockCode, Description, Quantity, UnitPrice, Country]
# Index: []

# %%
data.duplicated().sum()
# Out:
# 0

# %%
total_quantity = data['Quantity'].sum()
total_price = data['UnitPrice'].sum()

# Create a new one-row DataFrame to show totals
totals = pd.DataFrame({
    'Total_Quantity': [total_quantity],
    'Total_Price': [total_price]
})

totals
# Out:
#    Total_Quantity  Total_Price
# 0        20536106  20535773.54

# %%
print('Country count:')

data['Country'].value_counts()
# Out:
# Country count:
# Nigeria          14714
# Sierra Leone     14684
# Somalia          14656
# Cote d'Ivoire    14645
# Mozambique       14639
# Cameroon         14619
# Senegal          14616
# Benin            14610
# Ghana            14604
# Libya            14585
# Zimbabwe         14572
# Ethiopia         14565
# Rwanda           14563
# Togo             14560
# Morocco          14530
# Sudan            14530
# Kenya            14525
# Algeria          14492
# South Africa     14469
# Egypt            14456
# Niger            14455
# Tunisia          14452
# Uganda           14450
# Burkina Faso     14413
# Zambia           14397
# Tanzania         14390
# Mali             14319
# Madagascar       14319
# Name: Country, dtype: int64

# %%
print('Customer ID count:')

data['CustomerID'].value_counts()
# Out:
# Customer ID count:
# 17841.0    7983
# 14911.0    5903
# 14096.0    5128
# 12748.0    4642
# 14606.0    2782
#            ...
# 15070.0       1
# 15753.0       1
# 17065.0       1
# 16881.0       1
# 16995.0       1
# Name: CustomerID, Length: 4372, dtype: int64

# %%
print("Country VS. Customer ID  count:") 

data[['Country','CustomerID']].value_counts()
# Out:
# Country VS. Customer ID  count:
# Country       CustomerID
# Libya         17841.0       324
# Senegal       17841.0       311
# Burkina Faso  17841.0       308
# Mozambique    17841.0       303
# Uganda        17841.0       301
#                            ...
# Ghana         14022.0         1
#               14024.0         1
#               14037.0         1
# Somalia       14077.0         1
# South Africa  14576.0         1
# Length: 84912, dtype: int64

# %%
print("Customer ID VS. Invoice Number count:")

data[['CustomerID','InvoiceNo']].value_counts()
# Out:
# Customer ID VS. Invoice Number count:
# CustomerID  InvoiceNo
# 14096.0     576339       542
#             579196       533
#             580727       529
#             578270       442
#             573576       435
#                         ...
# 14744.0     C544590        1
# 17423.0     C553486        1
#             C572747        1
# 17425.0     577553         1
# 12346.0     541431         1
# Length: 22190, dtype: int64

# %%
print('Invoice Number count:')

data['InvoiceNo'].value_counts()
# Out:
# Invoice Number count:
# 576339    542
# 579196    533
# 580727    529
# 578270    442
# 573576    435
#          ...
# 554155      1
# 570248      1
# 545414      1
# 545418      1
# 565192      1
# Name: InvoiceNo, Length: 22190, dtype: int64

# %%
print('Invoice Date count:')

data['InvoiceDate'].value_counts()
# Out:
# Invoice Date count:
# 2011-11-14 15:27:00    543
# 2011-11-28 15:54:00    534
# 2011-05-12 17:17:00    530
# 2011-11-23 13:39:00    444
# 2011-10-31 14:09:00    436
#                       ...
# 2011-11-15 10:54:00      1
# 2011-08-04 13:20:00      1
# 2011-09-15 17:02:00      1
# 2011-09-15 16:57:00      1
# 2011-03-21 11:02:00      1
# Name: InvoiceDate, Length: 20460, dtype: int64

# %%
print("Total Number of Duplicate:")

data.duplicated(['InvoiceDate']).sum()
# Out:
# Total Number of Duplicate:
# 386369

# %%
print("Customer ID VS. Quantity Sold count:")

data[['CustomerID','Quantity']].value_counts()
# Out:
# Customer ID VS. Quantity Sold count:
# CustomerID  Quantity
# 17841.0     98          104
#             24          102
#             26          101
#             31           95
#             6            94
#                        ...
# 14920.0     47            1
#             46            1
#             45            1
#             37            1
# 15291.0     17            1
# Length: 179093, dtype: int64

# %%
# Create a new column for Month-Year
data['Month'] = data['InvoiceDate'].dt.to_period('M')

# Calculate monthly sales
monthly_sales = data.groupby('Month')['Quantity'].sum()

# Plot sales trends
monthly_sales.plot(kind='line', figsize=(12, 6), marker='o')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Quantity Sold')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
data.head()
# Out:
#   InvoiceNo         InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365 2010-01-12 08:26:00     17850.0    SC1734  Electronics        65
# 1    536365 2010-01-12 08:26:00     17850.0    SC2088    Furniture        95
# 2    536365 2010-01-12 08:26:00     17850.0    SC3463        Books        78
# 3    536365 2010-01-12 08:26:00     17850.0    SC6228         Toys        15
# 4    536365 2010-01-12 08:26:00     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country    Month
# 0      10.23         Egypt  2010-01
# 1      19.61          Mali  2010-01
# 2      61.49          Mali  2010-01
# 3      24.73  South Africa  2010-01
# 4      38.83        Rwanda  2010-01

# %%
print("Description VS. Quantity Sold count:")

data[['Description','Quantity']].value_counts()
# Out:
# Description VS. Quantity Sold count:
# Description       Quantity
# Cosmetics         81          471
# Sports Equipment  36          467
# Kitchenware       72          466
# Electronics       61          459
# Shoes             91          458
#                              ...
#                   53          355
# Kitchenware       59          352
# Furniture         2           351
# Cloths            30          350
# Kitchenware       76          331
# Length: 1000, dtype: int64

# %%
product_sales = data.groupby('Description')['Quantity'].sum().sort_values(ascending=False)
print(product_sales)
# Out:
# Description
# Shoes               2069190
# Jewelry             2065153
# Toys                2063396
# Furniture           2063221
# Sports Equipment    2060571
# Cloths              2054709
# Cosmetics           2051088
# Kitchenware         2046704
# Electronics         2036733
# Books               2025341
# Name: Quantity, dtype: int64

# %%
# Plot top 10 selling products
top_products = product_sales.head(10)

top_products.plot(kind='barh', figsize=(10, 6), color='skyblue')
plt.title('Top 10 Products by Quantity Sold')
plt.xlabel('Quantity Sold')
plt.ylabel('Product Description')
plt.gca().invert_yaxis()  # Highest at top
plt.tight_layout()
plt.show()

# %%
data.head()
# Out:
#   InvoiceNo         InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365 2010-01-12 08:26:00     17850.0    SC1734  Electronics        65
# 1    536365 2010-01-12 08:26:00     17850.0    SC2088    Furniture        95
# 2    536365 2010-01-12 08:26:00     17850.0    SC3463        Books        78
# 3    536365 2010-01-12 08:26:00     17850.0    SC6228         Toys        15
# 4    536365 2010-01-12 08:26:00     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country    Month
# 0      10.23         Egypt  2010-01
# 1      19.61          Mali  2010-01
# 2      61.49          Mali  2010-01
# 3      24.73  South Africa  2010-01
# 4      38.83        Rwanda  2010-01

# %%
# Create cohort by getting the customer's first purchase month
data['CohortMonth'] = data.groupby('CustomerID')['InvoiceDate'].transform('min').dt.to_period('M')
# data['OrderMonth'] = data['InvoiceDate'].dt.to_period('M')

# Calculate time offset in months between first purchase and current order
data['CohortIndex'] = (data['Month'] - data['CohortMonth']).apply(attrgetter('n'))

# Count unique users in each cohort per month offset
cohort_data = data.groupby(['CohortMonth', 'CohortIndex'])['CustomerID'].nunique().unstack(0)

# Plot heatmap
plt.figure(figsize=(14, 7))
sns.heatmap(cohort_data.T, annot=True, fmt='g', cmap='YlGnBu')
plt.title('Cohort Analysis - User Retention')
plt.xlabel('Months since First Purchase')
plt.ylabel('Cohort (Month)')
plt.show()

# %%
# Month 0 = size of each cohort
cohort_sizes = cohort_data.iloc[0]
retention = cohort_data.divide(cohort_sizes, axis=1).round(3)

# Set figure size BEFORE plotting
plt.figure(figsize=(14, 8))
sns.heatmap(retention.T * 100, annot=True, fmt='.1f', cmap='magma')

plt.title('Cohort Analysis - Retention Rate (%)')
plt.xlabel('Cohort Index (Months Since First Purchase)')
plt.ylabel('Cohort Month')
plt.tight_layout()
plt.show()

# %%
print(h)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7916\259929948.py in <module>
# ----> 1 print(h)
#
# NameError: name 'h' is not defined

# %%
# Total purchases per customer
purchase_distribution = data.groupby('CustomerID')['Quantity'].sum()

# Histogram
plt.figure(figsize=(12, 6))
plt.hist(purchase_distribution, bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of Total Quantity Purchased per Customer')
plt.xlabel('Total Quantity Purchased')
plt.ylabel('Number of Customers')
plt.tight_layout()
plt.show()

# %%
# Set snapshot date as the day after the last transaction
snapshot_date = data['InvoiceDate'].max() + pd.Timedelta(days=1)

# Calculate RFM + Tenure
rfm = data.groupby('CustomerID').agg({
    'InvoiceDate': [
        lambda x: (snapshot_date - x.max()).days,     # Recency
        lambda x: (snapshot_date - x.min()).days,     # Tenure
    ],
    'InvoiceNo': 'nunique',                           # Frequency
    'Quantity': 'sum'                                 # Monetary (proxy)
})

# Rename columns
rfm.columns = ['Recency', 'Tenure', 'Frequency', 'Monetary']
rfm = rfm.reset_index()
rfm
# Out:
#       CustomerID  Recency  Tenure  Frequency  Monetary
# 0        12346.0      327     327          2       119
# 1        12347.0       41     517          7      8511
# 2        12348.0       77     359          4      1539
# 3        12349.0       20      20          1      3434
# 4        12350.0      312     312          1       917
# ...          ...      ...     ...        ...       ...
# 4367     18280.0      161     161          1       495
# 4368     18281.0        5       5          1       379
# 4369     18282.0       94     302          3       786
# 4370     18283.0       11     322         16     40533
# 4371     18287.0        1     203          3      4173
#
# [4372 rows x 5 columns]

# %%
# Create TotalPrice column
data['TotalPrice'] = data['Quantity'] * data['UnitPrice']

# RFM with Monetary based on actual revenue
rfm = data.groupby('CustomerID').agg({
    'InvoiceDate': [
        lambda x: (snapshot_date - x.max()).days,     # Recency
        lambda x: (snapshot_date - x.min()).days,     # Tenure
    ],
    'InvoiceNo': 'nunique',                           # Frequency
    'TotalPrice': 'sum'                               # Monetary (actual)
})

rfm.columns = ['Recency', 'Tenure', 'Frequency', 'Monetary']
rfm = rfm.reset_index()

# %%
rfm
# Out:
#       CustomerID  Recency  Tenure  Frequency    Monetary
# 0        12346.0      327     327          2     5342.40
# 1        12347.0       41     517          7   431501.00
# 2        12348.0       77     359          4    82378.47
# 3        12349.0       20      20          1   176075.12
# 4        12350.0      312     312          1    48173.37
# ...          ...      ...     ...        ...         ...
# 4367     18280.0      161     161          1    18907.36
# 4368     18281.0        5       5          1    26009.01
# 4369     18282.0       94     302          3    36010.74
# 4370     18283.0       11     322         16  2008747.62
# 4371     18287.0        1     203          3   209057.23
#
# [4372 rows x 5 columns]

# %%
# Recency score (lower is better)
rfm['R_Score'] = pd.qcut(rfm['Recency'], 4, labels=[4, 3, 2, 1])

# Frequency score (higher is better)
rfm['F_Score'] = pd.qcut(rfm['Frequency'].rank(method='first'), 4, labels=[1, 2, 3, 4])

# Monetary score (higher is better)
rfm['M_Score'] = pd.qcut(rfm['Monetary'], 4, labels=[1, 2, 3, 4])

# Combine into RFM segment
rfm['RFM_Segment'] = rfm['R_Score'].astype(str) + rfm['F_Score'].astype(str) + rfm['M_Score'].astype(str)

# Optionally: Add an RFM score total
rfm['RFM_Score'] = rfm[['R_Score', 'F_Score', 'M_Score']].astype(int).sum(axis=1)

# %%
# how to save RFM to excel file
rfm.to_excel('customer_rfm_scored.xlsx', index=False)

# %%
print(yfvd)
